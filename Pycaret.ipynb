# %%
# !pip install pycaret
# !pip install shap

# %%
import pycaret
from pycaret.datasets import get_data
index = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
data = get_data('wine')
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality type
# 0      9.4        5  red
# 1      9.8        5  red
# ...

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
# !pip install numba==0.53
# Out:
# WARNING: Ignoring invalid distribution -tatsmodels (/usr/local/lib/python3.7/dist-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (/usr/local/lib/python3.7/dist-packages)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 3.4 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 25.3 MB 1.9 MB/s
# ...
# WARNING: Ignoring invalid distribution -tatsmodels (/usr/local/lib/python3.7/dist-packages)
# ...
#   Attempting uninstall: llvmlite
#     WARNING: Ignoring invalid distribution -tatsmodels (/usr/local/lib/python3.7/dist-packages)
#     Found existing installation: llvmlite 0.37.0
#     Uninstalling llvmlite-0.37.0:
#       Successfully uninstalled llvmlite-0.37.0
#   Attempting uninstall: numba
#     WARNING: Ignoring invalid distribution -tatsmodels (/usr/local/lib/python3.7/dist-packages)
#     Found existing installation: numba 0.54.1
#     Uninstalling numba-0.54.1:
# ...

# %%
from pycaret.classification import *
clfl = setup(data, target='quality' , session_id=123, experiment_name="wine_ex", normalize=True, feature_selection=True )
# Out:
#                                Description            Value
# 0                               session_id              123
# 1                                   Target          quality
# 2                              Target Type       Multiclass
# 3                            Label Encoded             None
# 4                            Original Data       (6497, 13)
# 5                           Missing Values            False
# 6                         Numeric Features               11
# 7                     Categorical Features                1
# 8                         Ordinal Features            False
# 9                High Cardinality Features            False
# 10                 High Cardinality Method             None
# 11                   Transformed Train Set       (4547, 11)
# 12                    Transformed Test Set       (1950, 11)
# 13                      Shuffle Train-Test             True
# 14                     Stratify Train-Test            False
# ...

# %%
training_data = get_config(variable = 'X_train')
training_data
# Out:
# INFO:logs:Initializing get_config()
# INFO:logs:get_config(variable=X_train)
# INFO:logs:Global variable: X_train returned as       free sulfur dioxide  residual sugar  volatile acidity   density  \
# 2457             1.636008        0.978088         -0.720134  0.839105
# 524             -0.430245       -0.642230          0.561941  0.954463
# 4551            -1.212070       -0.766870         -0.414878 -0.594635
# 5954             0.184047       -0.621456         -0.170673 -1.728449
# 3759            -0.095177        0.874222         -0.048571  0.229351
# ...                   ...             ...               ...       ...
# 5218            -0.206866        4.270658          0.684043  2.717774
# 4060            -1.100381       -0.600683         -0.475929 -0.225498
# 1346            -1.435449       -0.704550          1.538759  0.005217
# 3454             2.920436        1.767474         -0.720134  1.119248
# 3582             1.245096        1.809021         -0.842236  1.415894
#
# ...

# %%
training_data.shape
# Out:
# (4547, 11)

# %%
models()
# Out:
# INFO:logs:gpu_param set to False
# WARNING:logs:Wrong xgboost version. Expected xgboost>=1.1.0, got xgboost==0.90
# WARNING:logs:Couldn't import catboost.CatBoostClassifier
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# rbfsvm                SVM - Radial Kernel
# gpc           Gaussian Process Classifier
# mlp                        MLP Classifier
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
# ...

# %%
best_model = compare_models()
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# et                 Extra Trees Classifier    0.6683  0.3412  0.3840  0.6700
# rf               Random Forest Classifier    0.6657  0.3380  0.3736  0.6680
# lightgbm  Light Gradient Boosting Machine    0.6391  0.3266  0.3696  0.6356
# gbc          Gradient Boosting Classifier    0.5923  0.3083  0.3023  0.5868
# dt               Decision Tree Classifier    0.5843  0.2745  0.3625  0.5829
# knn                K Neighbors Classifier    0.5483  0.2913  0.3040  0.5331
# lr                    Logistic Regression    0.5428  0.2906  0.2342  0.5065
# lda          Linear Discriminant Analysis    0.5346  0.2901  0.2460  0.5044
# ridge                    Ridge Classifier    0.5302  0.0000  0.2152  0.4664
# qda       Quadratic Discriminant Analysis    0.4871  0.2774  0.3082  0.4957
# svm                   SVM - Linear Kernel    0.4858  0.0000  0.2190  0.4442
# ...

# %%
best_model
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)

# %%
tuned_et = tune_model(best_model)
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.4945  0.0000  0.2220  0.4519  0.4525  0.1725  0.1818
# 1       0.5473  0.0000  0.2421  0.5351  0.4948  0.2483  0.2698
# 2       0.5297  0.0000  0.2408  0.5280  0.4873  0.2264  0.2404
# 3       0.5495  0.7267  0.2117  0.5160  0.5033  0.2588  0.2755
# 4       0.5538  0.7288  0.2183  0.5348  0.5136  0.2708  0.2845
# 5       0.5604  0.7452  0.2139  0.5156  0.5102  0.2766  0.2948
# 6       0.5824  0.7520  0.2217  0.5703  0.5265  0.3091  0.3334
# 7       0.5176  0.0000  0.2303  0.4817  0.4703  0.2059  0.2190
# 8       0.5661  0.0000  0.2519  0.5497  0.5110  0.2845  0.3026
# 9       0.5220  0.0000  0.2334  0.4911  0.4772  0.2116  0.2260
# Mean    0.5423  0.2953  0.2286  0.5174  0.4947  0.2464  0.2628
# Std     0.0249  0.3617  0.0126  0.0329  0.0216  0.0397  0.0431
# INFO:logs:create_model_container: 30
# INFO:logs:master_model_container: 30
# INFO:logs:display_container: 5
# ...

# %%
plot_model(tuned_et)
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() succesfully completed......................................

# %%
plot_model(tuned_et , plot='feature')
# Out:
# INFO:logs:Visual Rendered Successfully
# INFO:logs:plot_model() succesfully completed......................................

# %%
interpret_model(tuned_et)
# Out:
# INFO:logs:Initializing interpret_model()
# INFO:logs:interpret_model(estimator=ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight={},
#                      criterion='entropy', max_depth=5, max_features=1.0,
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0002, min_impurity_split=None,
#                      min_samples_leaf=5, min_samples_split=10,
#                      min_weight_fraction_leaf=0.0, n_estimators=150, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False), use_train_data=False, X_new_sample=None, y_new_sample=None, feature=None, kwargs={}, observation=None, plot=summary, save=False)
# INFO:logs:Checking exceptions
# INFO:logs:plot type: summary
# INFO:logs:Creating TreeExplainer
# INFO:logs:Compiling shap values
# INFO:logs:Visual Rendered Successfully
# ...
